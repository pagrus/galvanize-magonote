# %%
import os
import magonote_functions as mf
import random
import pandas as pd
import numpy as np

# %%
post_info_csv = 'data/post_info.csv'
df = pd.read_csv(post_info_csv, sep='\t', index_col=0)
df
# Out:
#         trail anchor count                                  trail anchor zero  \
# 64177                    0                                                NaN
# 248895                   1  <a class="trail" href="https://denki.itch.io/a...
# 93198                    1  <a class="trail" href="https://vonlehecreative...
# 177221                   0                                                NaN
# 113036                   0                                                NaN
# 192541                   2  <a class="trail" href="/jam/try-something-new-...
# 59865                    1  <a class="trail" href="https://oxysofts.itch.i...
# 236952                   2  <a class="trail" href="/jam/gmtk-jam">Game Mak...
# 110414                   1  <a class="trail" href="https://golden-unicorn-...
# 162886                   1  <a class="trail" href="https://pankamil.itch.i...
# 120339                   0                                                NaN
# ...
