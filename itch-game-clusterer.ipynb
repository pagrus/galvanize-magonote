# %%
import os
import magonote_functions as mf
import random
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
game_info_csv = 'data/game_info.csv'
game_info_df = pd.read_csv(game_info_csv, sep='\t', index_col=0)
game_info_df
# Out:
#                                                title text  \
# 91140                                       Away - GBJam5
# 134059                                     Aftermath Demo
# 91190                               The Terror Of Matthew
# 221027                             Ninja Toy - World Hero
# 144235                                    ScrapYard ALPHA
# 140120                                        World Mower
# 101684                            The story about racoons
# 136453                               Jam's prison prova 2
# 94079                       P.tree: Single-Cell Simulator
# 220320                                               META
# 151856                                   Drone Landing 2D
# 207724                                Naughts and Crosses
# 144357                                               Gib!
# 154238                                        FrogestJump
# 210513                                       Satan Skates
# 212763                                          Dead Ends
# 152834                                 The Lands of Chaos
# 155649               Wisdom Of The Insane DEMO VERSION #2
# 159432                 GunyMcGunFace VS Celestial Horrors
# 94350                                        Pinguin 2000
# 90526                       Grimoire - Puzzles & Monsters
# 142501                                  Kill The Streamer
# 154702                                          Palladawn
# 208800                                         Sleepy Boy
# 90963                                          Cannonauts
# 88570                                               arrpg
# 145824                                    WillO Revisited
# 212432                                 The Epic Gang Plus
# 213763                                             Blower
# 95458                                         Caterpillar
# ...                                                   ...
# 150992                                     One Small Step
# 214803                                      Hide The Body
# 90785                                            Wormhole
# 159856                                                FEn
# 95647                                           Moonspire
# 219239                              The Last One Standing
# 215977                                  Cut Down Trees!!!
# 146221                        BreakOut Supremo do Matheus
# 140569                               Smash the Patriarchy
# 94315                                      It's OK: Tacos
# 137264                                      Shichikashuku
# 134938                                  Bear Beware (C64)
# 95786                                 The room is on fire
# 146927                                  Super Space Snake
# 158355                                       Union Knight
# 212371                                         SledFree:D
# 88474   UEBERNATURAL - THE VIDEO GAME (Supernatural Fa...
# 210632                                      No Man's Land
# 88046                                           Nodevious
# 218406                                    Jenga Simulator
# 150524                                            Mirrors
# 146150                                       Folkloristic
# 96357                                            bug game
# 101625                                    Brewing Potions
# 98589                                            Sky High
# 154743                                             Plinko
# 216004                                          Phantasma
# 90370                                                 217
# 209858                                           Farmorea
# 97314                  Super Ghost Ball  - The Life Spark
#
#                   creator text                         creator url  \
# 91140                dgoldaraz           https://dgoldaraz.itch.io
# 134059              MattWillis          https://mattwillis.itch.io
# 91190             VictorBurgos        https://victorburgos.itch.io
# 221027                  Rombus              https://rombus.itch.io
# 144235      ByteRockers' Games   https://byterockers-games.itch.io
# 140120  Fellowship of the Game            https://fog-icmc.itch.io
# 101684       ThinkingMicrowave   https://thinkingmicrowave.itch.io
# 136453              jaspel_jam          https://jaspel-jam.itch.io
# 94079              Zane Hedges     https://chemistrychrist.itch.io
# 220320                  digaly              https://digaly.itch.io
# 151856       letsgetnerdygames   https://letsgetnerdygames.itch.io
# 207724           NycripStudios       https://nycripstudios.itch.io
# 144357                  trumad              https://trumad.itch.io
# 154238               Gebowunjo           https://gebowunjo.itch.io
# 210513         LeatherIceCream     https://leathericecream.itch.io
# 212763                  Sam Q.         https://samwiththej.itch.io
# 152834             Lepidoptera         https://lepidoptera.itch.io
# 155649             thomaaasmix         https://thomaaasmix.itch.io
# 159432      ekaperiodictable11  https://ekaperiodictable11.itch.io
# 94350             Metricsystem        https://metricsystem.itch.io
# 90526               NinjaMan Z          https://ninjaman-z.itch.io
# 142501         KillTheStreamer     https://killthestreamer.itch.io
# 154702             Cdoorstudio         https://cdoorstudio.itch.io
# 208800             Sleepy Sora         https://sleepy-sora.itch.io
# 90963                  defacid             https://defacid.itch.io
# 88570                     road                https://road.itch.io
# 145824           Chequered Ink                  https://ci.itch.io
# 212432       Darkenauts_Studio   https://darkenauts-studio.itch.io
# 213763                GeekZmoD            https://geekzmod.itch.io
# 95458             BearlyDesign        https://bearlydesign.itch.io
# ...                        ...                                 ...
# 150992                   ABird               https://abird.itch.io
# 214803                Dansodic            https://dansodic.itch.io
# 90785             Celeste Chan         https://deligirlcee.itch.io
# 159856                 Kayriuu             https://kayriuu.itch.io
# 95647                 RGCD.DEV             https://rgcddev.itch.io
# 219239                 laurabf             https://laurabf.itch.io
# 215977                  Alysia              https://alysia.itch.io
# 146221            FranciscoSBJ        https://franciscosbj.itch.io
# 140569                   sward               https://sward.itch.io
# 94315           breakfastparty      https://breakfastparty.itch.io
# 137264         J.W.C. Warhurst                https://jwcw.itch.io
# 134938      Psytronik Software           https://psytronik.itch.io
# 95786                  mattgen             https://mattgen.itch.io
# 146927         Anxiety Monster     https://anxiety-monster.itch.io
# 158355           OlivierSchyns       https://olivierschyns.itch.io
# 212371           TwinGem Games        https://twingemgames.itch.io
# 88474               ILIKESCIFI          https://ilikescifi.itch.io
# 210632          LunarzoneGames      https://lunarzonegames.itch.io
# 88046                Iyashikei           https://iyashikei.itch.io
# 218406            dennyroberts        https://dennyroberts.itch.io
# 150524           CyanideLemons       https://cyanidelemons.itch.io
# 146150                Arbigaus            https://arbigaus.itch.io
# 96357                   shmoof              https://shmoof.itch.io
# 101625          BrewingPotions      https://brewingpotions.itch.io
# 98589                 MG Games            https://mg-games.itch.io
# 154743              snowhiterw          https://snowhiterw.itch.io
# 216004            PhantasmaBTK        https://phantasmabtk.itch.io
# 90370               remyripple          https://remyripple.itch.io
# 209858             PCattaGames           https://pcgamedev.itch.io
# 97314                 Stef3409            https://stef3409.itch.io
#
#                                                  game url  \
# 91140               https://dgoldaraz.itch.io/away-gbjam5
# 134059                  https://mattwillis.itch.io/amdemo
# 91190   https://victorburgos.itch.io/the-terror-of-mat...
# 221027        https://rombus.itch.io/ninja-toy-world-hero
# 144235        https://byterockers-games.itch.io/scrapyard
# 140120               https://fog-icmc.itch.io/world-mower
# 101684  https://thinkingmicrowave.itch.io/the-story-ab...
# 136453     https://jaspel-jam.itch.io/jams-prison-prova-2
# 94079   https://chemistrychrist.itch.io/ptree-single-c...
# 220320                        https://digaly.itch.io/meta
# 151856  https://letsgetnerdygames.itch.io/drone-landin...
# 207724  https://nycripstudios.itch.io/naughts-and-crosses
# 144357                         https://trumad.itch.io/gib
# 154238              https://gebowunjo.itch.io/frogestjump
# 210513       https://leathericecream.itch.io/satan-skates
# 212763              https://samwiththej.itch.io/dead-ends
# 152834     https://lepidoptera.itch.io/the-lands-of-chaos
# 155649  https://thomaaasmix.itch.io/wisdom-of-the-insa...
# 159432  https://ekaperiodictable11.itch.io/gunymcgunfa...
# 94350           https://metricsystem.itch.io/pinguin-2000
# 90526   https://ninjaman-z.itch.io/grimoire-puzzles-mo...
# 142501  https://killthestreamer.itch.io/kill-the-streamer
# 154702              https://cdoorstudio.itch.io/palladawn
# 208800             https://sleepy-sora.itch.io/sleepy-boy
# 90963                  https://defacid.itch.io/cannonauts
# 88570                          https://road.itch.io/arrpg
# 145824                 https://ci.itch.io/willo-revisited
# 212432  https://darkenauts-studio.itch.io/the-epic-gan...
# 213763                    https://geekzmod.itch.io/blower
# 95458             https://bearlydesign.itch.io/catapiller
# ...                                                   ...
# 150992               https://abird.itch.io/one-small-step
# 214803             https://dansodic.itch.io/hide-the-body
# 90785                https://deligirlcee.itch.io/wormhole
# 159856                        https://kayriuu.itch.io/fen
# 95647                   https://rgcddev.itch.io/moonspire
# 219239      https://laurabf.itch.io/the-last-one-standing
# 215977              https://alysia.itch.io/cut-down-trees
# 146221  https://franciscosbj.itch.io/breakout-supremo-...
# 140569         https://sward.itch.io/smash-the-patriarchy
# 94315              https://breakfastparty.itch.io/oktacos
# 137264                 https://jwcw.itch.io/shichikashuku
# 134938           https://psytronik.itch.io/bearbeware-c64
# 95786         https://mattgen.itch.io/the-room-is-on-fire
# 146927  https://anxiety-monster.itch.io/super-space-snake
# 158355         https://olivierschyns.itch.io/union-knight
# 212371             https://twingemgames.itch.io/sledfreed
# 88474   https://ilikescifi.itch.io/supernatural-the-vi...
# 210632        https://lunarzonegames.itch.io/no-mans-land
# 88046                 https://iyashikei.itch.io/nodevious
# 218406       https://dennyroberts.itch.io/jenga-simulator
# 150524              https://cyanidelemons.itch.io/mirrors
# 146150              https://arbigaus.itch.io/folkloristic
# 96357                     https://shmoof.itch.io/bug-game
# 101625    https://brewingpotions.itch.io/brewing-potionss
# 98589                   https://mg-games.itch.io/sky-high
# 154743                  https://snowhiterw.itch.io/plinko
# 216004             https://phantasmabtk.itch.io/phantasma
# 90370                      https://remyripple.itch.io/217
# 209858                 https://pcgamedev.itch.io/farmorea
# 97314   https://stef3409.itch.io/super-ghost-ball-the-...
#
#                                                 full text
# 91140   Away - GBJam5new I.HtmlEmbed('#html_embed_widg...
# 134059  Aftermath DemoA downloadable game for WindowsV...
# 91190   The Terror Of MatthewA downloadable game for W...
# 221027  Ninja Toy - World Heronew I.HtmlEmbed('#html_e...
# 144235  ScrapYard ALPHAA downloadable game for Windows...
# 140120  View all by Fellowship of the GameFollow Fello...
# 101684  View all by ThinkingMicrowaveFollow ThinkingMi...
# 136453  Jam's prison prova 2new I.HtmlEmbed('#html_emb...
# 94079   P.tree: Single-Cell SimulatorA downloadable ga...
# 220320  View all by digalyFollow digalyFollowing digal...
# 151856  Drone Landing 2DA downloadable gameAs a pilot ...
# 207724  Naughts and CrossesA downloadable game for Win...
# 144357  Gib!new I.HtmlEmbed('#html_embed_widget_4536',...
# 154238  View all by GebowunjoFollow GebowunjoFollowing...
# 210513  Satan Skatesnew I.HtmlEmbed('#html_embed_widge...
# 212763  Dead EndsA downloadable game for Windows and m...
# 152834  The Lands of Chaosnew I.HtmlEmbed('#html_embed...
# 155649  Wisdom Of The Insane DEMO VERSION #2A download...
# 159432  View all by ekaperiodictable11Follow ekaperiod...
# 94350   Pinguin 2000new I.HtmlEmbed('#html_embed_widge...
# 90526   View all by NinjaMan ZFollow NinjaMan ZFollowi...
# 142501  Kill The StreamerA downloadable game for Windo...
# 154702  PalladawnA downloadable game for WindowsCompet...
# 208800  View all by Sleepy SoraFollow Sleepy SoraFollo...
# 90963   CannonautsA downloadable game for Windows and ...
# 88570   arrpgA downloadable game\n\tThis is a mobile m...
# 145824  WillO RevisitedA downloadable game for Windows...
# 212432  The Epic Gang PlusA downloadable game for Wind...
# 213763  View all by GeekZmoDFollow GeekZmoDFollowing G...
# 95458   Caterpillarnew I.HtmlEmbed('#html_embed_widget...
# ...                                                   ...
# 150992  One Small StepA downloadable game for Windows,...
# 214803  Hide The BodyA downloadable game for WindowsBu...
# 90785   WormholeA downloadable game for macOSThis is w...
# 159856  FEnA downloadable game for WindowsA game. Shoo...
# 95647   MoonspireA downloadable Commodore 64 game for ...
# 219239  The Last One StandingA downloadable gameThis g...
# 215977  View all by AlysiaFollow AlysiaFollowing Alysi...
# 146221  BreakOut Supremo do Matheusnew I.HtmlEmbed('#h...
# 140569  Smash the Patriarchynew I.HtmlEmbed('#html_emb...
# 94315   View all by breakfastpartyFollow breakfastpart...
# 137264  ShichikashukuA downloadable game for WindowsSh...
# 134938  Bear Beware (C64)A downloadable gameBuy Now$2....
# 95786   Follow mattgenFollowing mattgenUnfollow mattge...
# 146927  Super Space Snakenew I.HtmlEmbed('#html_embed_...
# 158355  View all by OlivierSchynsFollow OlivierSchynsF...
# 212371  View all by TwinGem GamesFollow TwinGem GamesF...
# 88474   View all by ILIKESCIFIFollow ILIKESCIFIFollowi...
# 210632  No Man's LandA downloadable game for WindowsDo...
# 88046   Nodeviousnew I.HtmlEmbed('#html_embed_widget_4...
# 218406  Jenga Simulator Run gamenew I.HtmlEmbed('#html...
# 150524  MirrorsA downloadable game for WindowsMade in ...
# 146150  FolkloristicA downloadable game for WindowsDis...
# 96357   bug gameA downloadable game for Windowsyou're ...
# 101625  View all by BrewingPotionsFollow BrewingPotion...
# 98589   Sky Highnew I.HtmlEmbed('#html_embed_widget_66...
# 154743  Plinkonew I.HtmlEmbed('#html_embed_widget_5279...
# 216004  Follow PhantasmaBTKFollowing PhantasmaBTKUnfol...
# 90370   217A downloadable game for macOSA game as a se...
# 209858  FarmoreaA downloadable game for WindowsDownloa...
# 97314   Super Ghost Ball  - The Life SparkA downloadab...
#
# [5000 rows x 5 columns]

# %%
from sklearn.feature_extraction import text
add_stop_words = ('itchio', 'report', 'zip', 'view', 'comment', 'post', 'upvotes', 'account', 'post_id', 'report_url', 'io', 'game', 'nowname', 'priceclick', 'download', 'mb', 'downloadable', 'viewgame', 'user_tools', 'https', 'viewhtmlgame', 'start_maximized', 'htmlembed', 'play_after', 'itch', '_merchantsettings', 'document', 'apple', 'itunes', 'itunes_autolinkmaker', 'script', 'src', 'javascript', 'function', 'http', 'swf', 'flash', 'class', 'data', 'googleaccessid', 'gserviceaccount', 'signature', 'moonscript2', 'commondatastorage', 'div', 'js', 'span', 'default', 'var', 'usd', 'up_score', 'down_score', 'autolinkmaker', 'com', 'autolink','commentlog', 'html', 'play_url')
all_stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)
itch_stop_words=set(all_stop_words)

# %%
vectorizer = TfidfVectorizer(stop_words=itch_stop_words)
X = vectorizer.fit_transform(game_info_df['full text'])
features = vectorizer.get_feature_names()
n_clu = 6
kmeans = KMeans(n_clusters=n_clu)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
top_centroids = kmeans.cluster_centers_.argsort()[:,-1:-11:-1]
for num, centroid in enumerate(top_centroids):
    print("%d: %s" % (num, ", ".join(features[i] for i in centroid)))
# Out:
# 0: space, 3d, toolkit, new, maker, shooter, jam, shoot, leave, player
# 1: dare, ludum, 3d, 99, world, 38, small, new, purchase, apr
# 2: la, le, et, en, que, pour, les, jeu, el, des
# 3: 3d, rp, width, height, 90, false, new, type, id, freei
# 4: reply, days, ago, year, really, like, time, just, 3d, new
# 5: 3d, new, leave, freei, type, updated, id, loading, informationpublished, slug

# %%
vectorizer = TfidfVectorizer(stop_words=itch_stop_words, max_features=1000)
X = vectorizer.fit_transform(game_info_df['full text'])
features = vectorizer.get_feature_names()
kmeans = KMeans(n_clusters=n_clu)
kmeans.fit(X)
top_centroids = kmeans.cluster_centers_.argsort()[:,-1:-11:-1]
for num, centroid in enumerate(top_centroids):
    print("%d: %s" % (num, ", ".join(features[i] for i in centroid)))
# Out:
# 0: reply, days, ago, year, 3d, new, really, like, time, thanks
# 1: 3d, new, leave, freei, type, updated, id, slug, loading, loader_outer
# 2: dare, ludum, 38, 3d, small, world, apr, new, 24, leave
# 3: 3d, width, height, rp, 90, false, new, freei, type, id
# 4: 99, purchase, minimum, morein, order, lessi, price, 00, windowsbuy, 3d
# 5: 3d, new, leave, play, player, space, type, freei, id, updated

# %%
assigned_cluster = kmeans.transform(X).argmin(axis=1)
# assigned_cluster

# %%
for i in range(kmeans.n_clusters):
    cluster = np.arange(0, X.shape[0])[assigned_cluster==i]
    sample_games = np.random.choice(cluster, 3, replace=False)
    # print(sample_games)
    print("cluster %d:" % i)
    for game in sample_games:
        print("    %s" % game_info_df.iloc[game]['title text'])
# Out:
# cluster 0:
#     Less then a minute
#     THAT LIZARD STOLE MY LUNCH
#     Mine Swine
# cluster 1:
#     The Sorrows Of Young Werther
#     The Cave
#     Bubonic
# cluster 2:
#     It's A Small World
#     Duoregi
#     Escape From The Bottle
# cluster 3:
#     Dungeon Wizard
#     Min hjärna Orginal Edition
#     Block Breaker
# cluster 4:
#     The Communist Dogifesto
#     Kimmy
#     Tower Defence Demo
# cluster 5:
#     Steamed Hams but a Playable Remix
#     Angry Cats
#     Paddle Ping
