# %%
import os
import magonote_functions as mf
import random
import pandas as pd
import numpy as np

# %%
# ok we're assuming we have all the game data fetched already, and it's in html/game_pages
# I guess this would be considered the actual scraping part

game_page_dir = "html/game_pages"

game_list = [x for x in os.listdir(game_page_dir) if x[-5:] == ".html"]
random.shuffle(game_list)
single_game = game_list[13]

len(game_list)
# Out:
# 24675

# %%
single_game
# Out:
# '144447.html'

# %%
partial_game_list = game_list[113:126]

# %%
mylist = mf.get_game_info(partial_game_list, game_page_dir)

# %%
all_game_list = mf.get_game_info(game_list, game_page_dir)
# takes about 3m with 24675 games

# %%
df_cols = ['game name', 'creator name', 'creator url', 'game url']
g_info_df = pd.DataFrame(columns=df_cols)

# %%
for game in all_game_list:
    g_info_df.loc[game[0]] = [game[1], game[2], game[3], game[4]]

# %%
g_info_df
# Out:
#                                                 game name  \
# 99428                                            Radiance
# 138299                                     Fugitive 54-57
# 146061                                     The Voxel Maze
# 150184                                     Endless Runner
# 154224                                   Frogs Eats Flies
# 147397                                       #SaveJessica
# 135268                                     Run Zombie Run
# 96676                                         Crazy Maze!
# 211280                                            JAMBALL
# 145686                                         Rocket_man
# 172657                                             Unison
# 158965                                          Super Fly
# 131404                                           vivarium
# 144447                                       Monster Rush
# 161135                                          Hi or Not
# 145863                      CometQ - Endless Blockbreaker
# 211950                            Science Station Epsilon
# 137072  The Curious Adventures of Ant, the Inebriated Ant
# 96878                                             BAMLike
# 91133                                           Solo Pong
# 208872                                  Board Battlefield
# 7688                                           Hard.Point
# 221085                            Un Angel En El INFIERNO
# 148920                                      Mountain View
# 101207                                    Starship Escape
# 91309                                           Endaction
# 95549                                     Wacky Wheels HD
# 142450                                    Angle of Attack
# 208442                                        RoboZombies
# 140544                          A Small Hell - LD38 Compo
# ...                                                   ...
# 209097                  Sango - Tales from the Coral Cave
# 149682                                             Ariana
# 91162                                    Cobra Test Scene
# 144916                                        Circle Pong
# 134193                                Make your Adventure
# 211397                                    My Awesome Game
# 140903                                         Aliens 2.0
# 221159                 The Golden Letters Early Demo v0.5
# 149362                                              Snake
# 151274                                         Pasteroids
# 141990                                         EELemental
# 97131                                          Germ Eater
# 90787                                             Stutter
# 91743                                    Fluffy The Cloud
# 214140                                     Orbit Invasion
# 102382                              Super Planet Defender
# 217046                Blip Rider by DinethD, Nic Lyness,
# 135054                               Platman Worlds (C64)
# 135026                                           Dropship
# 161913           Sigrid: Det Inre Mörkret - Prolog (DEMO)
# 157771                                        Space Rocks
# 149550                                        Tic Tac Toe
# 206674                   8 Hour Jam Infinite Running Game
# 139571                                         Maze Tower
# 91946                                    Just Ignore Them
# 94265                             Shira : Tale Of Pumpkin
# 98511                                        Tunnel Flyer
# 162217             Making My First Horror Game [Beginner]
# 137845                                        DuckHunters
# 213886                      Fragment: Contours of a Dream
#
#                          creator name                           creator url  \
# 99428                   Selfish Dream         https://selfish-dream.itch.io
# 138299             sabertoothharambes    https://sabertoothharambes.itch.io
# 146061                        Nogitsu               https://nogitsu.itch.io
# 150184                        oscaral               https://oscaral.itch.io
# 154224                       Needless              https://needless.itch.io
# 147397                       jmazurek              https://jmazurek.itch.io
# 135268                 TryAgain Gamez         https://tryagaingamez.itch.io
# 96676                  Chris Rosewood         https://chrisrosewood.itch.io
# 211280                  kristiandixon         https://kristiandixon.itch.io
# 145686                     gWulfers88            https://gwulfers88.itch.io
# 172657                          tcmxx                 https://tcmxx.itch.io
# 158965                   Hobgoblin101          https://hobgoblin101.itch.io
# 131404  jph wacheski / iterationGAMES          https://jph_wacheski.itch.io
# 144447                     Stomstudio            https://stomstudio.itch.io
# 161135                Joakim Isaksson                https://sharpy.itch.io
# 145863                  Timothi Ellim          https://timothiellim.itch.io
# 211950                      snugsound             https://snugsound.itch.io
# 137072                       tdennist              https://tdennist.itch.io
# 96878          Ahmed Khalifa (Amidos)            https://amidos2006.itch.io
# 91133                      galjagames            https://galjagames.itch.io
# 208872           Surrealscape Studios  https://surrealscape-studios.itch.io
# 7688                Arcadium playware            https://l-tyrosine.itch.io
# 221085                cristopher nene       https://cristopher-nene.itch.io
# 148920             ThePenguinEmporium    https://thepenguinemporium.itch.io
# 101207                      noesgames             https://noesgames.itch.io
# 91309                       Velocitea             https://velocitea.itch.io
# 95549                     Ferocity 2D            https://ferocity2d.itch.io
# 142450                        xesenix               https://xesenix.itch.io
# 208442                       epicFooF              https://epicfoof.itch.io
# 140544                       PsycHead              https://psychead.itch.io
# ...                               ...                                   ...
# 209097                  Atelier Sentô          https://ateliersento.itch.io
# 149682                           dona                  https://dona.itch.io
# 91162                 unityassetdepot       https://unityassetdepot.itch.io
# 144916                        Ducktor           https://ducktor-cid.itch.io
# 134193                  Lanyu EStudio         https://lanyu-estudio.itch.io
# 211397                      pascaloon             https://pascaloon.itch.io
# 140903                     DamithWick            https://damithwick.itch.io
# 221159                         kindaw                https://kindaw.itch.io
# 149362       Zachary Seebeck (Xeinix)                https://xeinix.itch.io
# 151274                         tgarr0                https://tgarr0.itch.io
# 141990               TheEdgeOfThought      https://theedgeofthought.itch.io
# 97131                            germ                  https://germ.itch.io
# 90787                    JoshuaTextor          https://joshuatextor.itch.io
# 91743                         gl_itch               https://gl-itch.itch.io
# 214140                  mrome007unity         https://mrome007unity.itch.io
# 102382                    Rui Madeira                  https://ruim.itch.io
# 217046                        DinethD               https://dinethd.itch.io
# 135054             Psytronik Software             https://psytronik.itch.io
# 135026                          Arowx                 https://arowx.itch.io
# 161913                         Sigrid                https://sigrid.itch.io
# 157771                      seandugan             https://seandugan.itch.io
# 149550                      SaliaNifo             https://salianifo.itch.io
# 206674                        atoxiam               https://atoxiam.itch.io
# 139571                       be Slack               https://beslack.itch.io
# 91946                   Stranga Games               https://stranga.itch.io
# 94265                        megaeggz              https://megaeggz.itch.io
# 98511                       thewgreen             https://thewgreen.itch.io
# 162217                  RentalGamer91         https://rentalgamer91.itch.io
# 137845                    NullBlastio           https://nullblastio.itch.io
# 213886                     Somberhead            https://somberhead.itch.io
#
#                                                  game url
# 99428              https://selfish-dream.itch.io/radiance
# 138299  https://sabertoothharambes.itch.io/fugitive-54-57
# 146061             https://nogitsu.itch.io/the-voxel-maze
# 150184             https://oscaral.itch.io/endless-runner
# 154224          https://needless.itch.io/frogs-eats-flies
# 147397               https://jmazurek.itch.io/savejessica
# 135268       https://tryagaingamez.itch.io/run-zombie-run
# 96676            https://chrisrosewood.itch.io/crazy-maze
# 211280              https://kristiandixon.itch.io/jamball
# 145686              https://gwulfers88.itch.io/rocket-man
# 172657                       https://tcmxx.itch.io/unison
# 158965             https://hobgoblin101.itch.io/super-fly
# 131404              https://jph_wacheski.itch.io/vivarium
# 144447            https://stomstudio.itch.io/monster-rush
# 161135                   https://sharpy.itch.io/hi-or-not
# 145863  https://timothiellim.itch.io/cometq-endless-bl...
# 211950  https://snugsound.itch.io/science-station-epsilon
# 137072  https://tdennist.itch.io/the-curious-adventure...
# 96878                  https://amidos2006.itch.io/bamlike
# 91133                https://galjagames.itch.io/solo-pong
# 208872  https://surrealscape-studios.itch.io/board-bat...
# 7688                 https://l-tyrosine.itch.io/hardpoint
# 221085  https://cristopher-nene.itch.io/un-angel-en-el...
# 148920   https://thepenguinemporium.itch.io/mountain-view
# 101207          https://noesgames.itch.io/starship-escape
# 91309                 https://velocitea.itch.io/endaction
# 95549          https://ferocity2d.itch.io/wacky-wheels-hd
# 142450            https://xesenix.itch.io/angle-of-attack
# 208442               https://epicfoof.itch.io/robozombies
# 140544              https://psychead.itch.io/a-small-hell
# ...                                                   ...
# 209097                 https://ateliersento.itch.io/sango
# 149682                        https://dona.itch.io/ariana
# 91162    https://unityassetdepot.itch.io/cobra-test-scene
# 144916            https://ducktor-cid.itch.io/circle-pong
# 134193  https://lanyu-estudio.itch.io/make-your-adventure
# 211397          https://pascaloon.itch.io/my-awesome-game
# 140903               https://damithwick.itch.io/aliens-20
# 221159  https://kindaw.itch.io/the-golden-letters-earl...
# 149362                       https://xeinix.itch.io/snake
# 151274                  https://tgarr0.itch.io/pasteroids
# 141990        https://theedgeofthought.itch.io/eelemental
# 97131                     https://germ.itch.io/germ-eater
# 90787                https://joshuatextor.itch.io/stutter
# 91743            https://gl-itch.itch.io/fluffy-the-cloud
# 214140       https://mrome007unity.itch.io/orbit-invasion
# 102382         https://ruim.itch.io/super-planet-defender
# 217046                 https://dinethd.itch.io/blip-rider
# 135054       https://psytronik.itch.io/platman-worlds-c64
# 135026                     https://arowx.itch.io/dropship
# 161913  https://sigrid.itch.io/sigrid-det-inre-mrkret-...
# 157771              https://seandugan.itch.io/space-rocks
# 149550              https://salianifo.itch.io/tic-tac-toe
# 206674            https://atoxiam.itch.io/infinite-runner
# 139571                 https://beslack.itch.io/maze-tower
# 91946            https://stranga.itch.io/just-ignore-them
# 94265      https://megaeggz.itch.io/shira-tale-of-pumpkin
# 98511              https://thewgreen.itch.io/tunnel-flyer
# 162217  https://rentalgamer91.itch.io/making-my-first-...
# 137845            https://nullblastio.itch.io/duckhunters
# 213886  https://somberhead.itch.io/fragment-contours-o...
#
# [24675 rows x 4 columns]

# %%
pickle_name = 'comments_data.pkl'
csv_name = 'data/game_info.csv'

#pf_df.to_pickle(pickle_name)
g_info_df.to_csv(csv_name, sep='\t', encoding='utf-8')

# a 10000 line csv is 9.1MB
